# %% [markdown]
# python:.

# %% [raw]
#  .Python is simple and easy
#  .High Level Language
#  .Developed by Guido van Rossum
#  .portable

# %%
print ("hello world")
# Out:
# hello world

# %%
print ("my name is ahsan'.""my age is 17.")
# Out:
# my name is ahsan'.my age is 17.

# %%
print(17)
# Out:
# 17

# %%
name = "Ahsan ali"
Work = "AI Specialist"
age = 17
print(Work)
# Out:
# AI Specialist

# %% [markdown]
# (name = variable)
# (Ahsan Ali = value)

# %%
print ("my age is :",age)
# Out:
# my age is : 17

# %%
print(type(2.5))
print(type(17))
# Out:
# <class 'float'>
# <class 'int'>

# %% [markdown]
# (DataType)

# %% [raw]
# 1. integers = (23,67,9)
# 2. string = (Hello World ,abcd)
# 3. float = (23.9, 5.4, 00.8, 6.00)
# 4. boolean = (True ,False)
# 5. None = (a=none) #value doesnot store

# %%
b = 45
t = 5
c = b+t
print (c)
# Out:
# 50

# %%
print(2769+5689)
# Out:
# 8458

# %%
print('''2026 is 
the 'era' of AI''')
# Out:
# 2026 is
# the 'era' of AI

# %%
print("is the era of AI")
# Out:
# is the era of AI

# %%
print('''2026 is 
the 'era' of AI''')
# Out:
# 2026 is
# the 'era' of AI

# %% [markdown]
# (types of operaters)
# #that perform certain operation

# %% [raw]
# Arithmetic operater : (-, +, *, %, /, **)
# Rational /Comparison : (==, !=, <, >, <=, >=)
# Assignment : (=, +=, -=, *=, /=, %=, **=)
# Logical Operter :(not , and , or)

# %%
#Arithmetic operater
a = 9
b = 2
print (a - b)
print (a + b)
print (a * b)
print (a % b)
print (a / b)#reminder
print (a ** b)#a^b
# Out:
# 7
# 11
# 18
# 1
# 4.5
# 81

# %%
#Comparison operater
a = 50
b = 20
print (a == b)#equal sign
print (a != b)#not equal sign
print (a > b)
print (a < b)
print (a >= b)
print (a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %%
#Assignment operater
a = 11
num = a + 10 #11 + 10 = 21
print(num)
# Out:
# 21

# %%
a = 10
a /= 9
print("a :", a)
# Out:
# a : 1.1111111111111112

# %%
a = 11
a -= 9
print("a :", a)
# Out:
# a : 2

# %%
a = 10
a %= 9
print("a :", a)
# Out:
# a : 1

# %%
a = 10
a **= 9
print("a :", a)
# Out:
# a : 1000000000

# %%
#logical operater
a = 50
b = 30
print (not False)
print (not(a>b))
# Out:
# True
# False

# %%
value1 = 67
value2 = 61

print(value1 and value2)#both are True
print(value1 or value2)
print(not value1)
# Out:
# 61
# 67
# False

# %%
value1 = True
value2 = False

print(value1 and value2)#both are True
print(value1 or value2)
print(not value2)
# Out:
# False
# True
# True

# %%
value1 = True
value2 = True

print(value1 and value2)#both are True
print(value1 or value2)
print(not value2)
# Out:
# True
# True
# False

# %%
value1 = False
value2 = False

print(value1 and value2)#both are True
print(value1 or value2)
print(not value2)
# Out:
# False
# False
# True

# %%
name = input("enter your name:")
print("Welcome =", name)
# Out:
# enter your name: ahsan
# Welcome = ahsan

# %% [markdown]
# @

# %%
#write a program to input 2 number and  print their sum.
a = int(input("enter no a:"))
b = int(input("enter no b:"))

print("sum =", a + b)
# Out:
# enter no a: 78
# enter no b: 6
# sum = 84

# %%
#write a program to input 2 number and  print their average.
a = int(input("enter no a:"))
b = int(input("enter no b:"))

print("avg =", (a+b)/2)
# Out:
# enter no a: 50
# enter no b: 80
# avg = 65.0

# %%
#WAP to input 2 int num a  & b  print True  if a  is greater than  or equal to b if not print False
a = int(input("enter no a:"))
b = int(input("enter no b:"))
print(a >= b)
# Out:
# enter no a: 4
# enter no b: 7
# False

# %%
a = 4 ** 3
c = a
print (c)
# Out:
# 64

# %%
a = ()
print(a)
# Out:
# ()

# %%
a = 9
print(a)
# Out:
# 9

# %%
a = None
print(a)
# Out:
# None

# %%
a = None
print(a)
# Out:
# None

# %%
b = int(input("enter no b:"))
h = int(input("enter no h:"))
print("sum",b + h)
# Out:
# enter no b: 8
# enter no h: 9
# sum 17
